# %% [markdown]
# <a href="https://colab.research.google.com/github/MatanLeybo/Classification-using-deep-learning/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installing the Kaggle library
# !pip install kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# configuring the path of Kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d salader/dogs-vs-cats
# Out:
# Dataset URL: https://www.kaggle.com/datasets/salader/dogs-vs-cats
# License(s): unknown
# ...
#  99% 1.06G/1.06G [00:05<00:00, 205MB/s]
# 100% 1.06G/1.06G [00:05<00:00, 216MB/s]

# %%
from IPython.display import clear_output, Image, display, HTML
import zipfile
zip_ref= zipfile.ZipFile('/content/dogs-vs-cats.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout
import time
import torch
import torchvision
from torch.utils.data import Dataset
from torchvision import transforms
import albumentations
import albumentations.pytorch
from matplotlib import pyplot as plt
import cv2
import numpy as np
import argparse
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import torch.nn as nn
import torch.optim as optim
from torchvision.models import resnet18
from torchvision import datasets, models, transforms
import os
import time
from keras import optimizers
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.16 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
from keras import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout

# %%
df_train = keras.utils.image_dataset_from_directory(
    directory = '/content/dogs_vs_cats/train',
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=32,
    image_size=(150, 150),

)

df_test = keras.utils.image_dataset_from_directory(
    directory = '/content/dogs_vs_cats/test',
   labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=32,
    image_size=(150, 150),
    )
# Out:
# Found 20000 files belonging to 2 classes.
# Found 5000 files belonging to 2 classes.

# %%
df_test
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
def plot_images(images, labels, num_images=9):
    plt.figure(figsize = [10, 8])
    for i in range(num_images):
        plt.subplot(3, 3, i+ 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(labels[i].numpy())

# %%
for images, labels in df_train.take(1):
    plot_images(images, labels)
    plt.show()

# %%
import tensorflow


def process(image, label):
    image = tensorflow.cast(image/255, tensorflow.float32)
    return image, label
df_train = df_train.map(process)
df_test = df_test.map(process)

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), padding='valid', activation = 'relu', input_shape=(150, 150, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2), strides = 2, padding = 'valid'))


model.add(Conv2D(64, kernel_size=(3, 3), padding='valid', activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2), strides = 2, padding = 'valid'))

model.add(Conv2D(128, kernel_size=(3, 3), padding='valid', activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2), strides = 2, padding = 'valid'))

model.add(Flatten())

model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Dense(64, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 148, 148, 32)        │             128 │
# ...

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])
history = model.fit(df_train, epochs =60, validation_data = df_test, callbacks = callbacks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-87910f149e62> in <cell line: 2>()
#       1 model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])
# ----> 2 history = model.fit(df_train, epochs =60, validation_data = df_test, callbacks = callbacks)
#
# NameError: name 'callbacks' is not defined

# %%
test_loss, test_accuracy = model.evaluate(df_test)

# Print the validation loss and accuracy
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - accuracy: 0.4947 - loss: 0.6932
# Test Loss: 0.6930881142616272
# Test Accuracy: 0.5012000203132629

# %%
plt.figure(figsize = [15, 5])
plt.subplot(1, 2, 1)
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('Model accuracy before Augmentation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])


plt.figure(figsize = [15, 5])
plt.subplot(1, 2, 1)
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model loss before Augmentation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d1abb2cffeab> in <cell line: 3>()
#       1 plt.figure(figsize = [15, 5])
#       2 plt.subplot(1, 2, 1)
# ----> 3 plt.plot(history1.history['accuracy'])
#       4 plt.plot(history1.history['val_accuracy'])
#       5 plt.title('Model accuracy before Augmentation')
#
# NameError: name 'history1' is not defined

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_gen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

test_gen = ImageDataGenerator(
        rescale=1./255
)

# %%
batch_size = 32

df_train = train_gen.flow_from_directory(
    '/content/dogs_vs_cats/train',
    target_size = (150, 150),
    batch_size = 64,
    class_mode = 'binary'
)


df_test = test_gen.flow_from_directory(
    '/content/dogs_vs_cats/test',
    target_size = (150, 150),
    batch_size = batch_size,
    class_mode = 'binary'
)
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %%
df_train

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
history1 = model.fit(df_train, epochs =10, validation_data = df_test)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 177s 518ms/step - accuracy: 0.6081 - loss: 0.7271 - val_accuracy: 0.5580 - val_loss: 0.7409
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 179s 471ms/step - accuracy: 0.6736 - loss: 0.6042 - val_accuracy: 0.5718 - val_loss: 0.7101
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 200s 465ms/step - accuracy: 0.7213 - loss: 0.5459 - val_accuracy: 0.7094 - val_loss: 0.5379
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 145s 457ms/step - accuracy: 0.7408 - loss: 0.5139 - val_accuracy: 0.7548 - val_loss: 0.4921
# Epoch 5/10
# ...

# %%
history1

# %%
plt.figure(figsize = [15, 5])
plt.subplot(1, 2, 1)
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('Model accuracy before Augmentation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

plt.subplot(1, 2, 2)
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('Model accuracy after Augmentation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()

plt.figure(figsize = [15, 5])
plt.subplot(1, 2, 1)
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model loss before Augmentation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])

# %%
plt.figure(figsize = [15, 5])
plt.subplot(1, 2, 1)
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('Model accuracy before Augmentation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])

plt.subplot(1, 2, 2)
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model accuracy after Augmentation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
plt.figure(figsize = [15, 5])
plt.subplot(1, 2, 1)
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss before Augmentation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])


plt.subplot(1, 2, 2)
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model loss after Augmentation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
loss, acc = model.evaluate(df_test)
print("Accuracy", acc)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - accuracy: 0.8088 - loss: 0.4055
# Accuracy 0.8199999928474426

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau , CSVLogger

checkpoint_filepath = '/tmp/ckpt/checkpoint.model.keras'

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy',
                                            patience= 4,
                                            verbose= 1,
                                            factor= 0.75,
                                            min_lr= 0.00001)

early_stopping = EarlyStopping(patience = 10)


checkpoint_acc = keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath,
    monitor = "val_accuracy",
    save_best_only = True, save_freq= 'epoch' )

filename='log.csv'
history_logger= CSVLogger(filename, separator=",", append=True)


callbacks = [learning_rate_reduction, early_stopping,
             checkpoint_acc, history_logger]

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])
history = model.fit(df_train, epochs =60, validation_data = df_test, callbacks = callbacks)
# Out:
# Epoch 1/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 131s 391ms/step - accuracy: 0.8453 - loss: 0.3424 - val_accuracy: 0.8268 - val_loss: 0.4130 - learning_rate: 0.0010
# Epoch 2/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 122s 382ms/step - accuracy: 0.8668 - loss: 0.3132 - val_accuracy: 0.8686 - val_loss: 0.3043 - learning_rate: 0.0010
# Epoch 3/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 122s 382ms/step - accuracy: 0.8711 - loss: 0.3053 - val_accuracy: 0.8882 - val_loss: 0.2673 - learning_rate: 0.0010
# Epoch 4/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 122s 382ms/step - accuracy: 0.8722 - loss: 0.2976 - val_accuracy: 0.7888 - val_loss: 0.4687 - learning_rate: 0.0010
# Epoch 5/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 122s 380ms/step - accuracy: 0.8743 - loss: 0.2857 - val_accuracy: 0.8806 - val_loss: 0.2790 - learning_rate: 0.0010
# Epoch 6/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 122s 381ms/step - accuracy: 0.8821 - loss: 0.2746 - val_accuracy: 0.8478 - val_loss: 0.3502 - learning_rate: 0.0010
# Epoch 7/60
# ...

# %%
dataset = load_dataset("train")

# %%
from PIL import Image
import glob

for infile in glob.glob("*.jpg"):
    im = Image.open("test")

# %%
infile

# %%
dataset

# %%
dataset['train']['image'][3]

# %%
dataset.set_transform(transforms)

# %%
train_ds

# %%
smaller_train_ds = train_ds.take(50)
smaller_validation_ds = validation_ds.take(20)

# %%
validation_ds

# %%
# prompt: train_ds

train_ds

# %%
model = tf.keras.Sequential()

model.add(Conv2D(32, kernel_size = (3,3), padding = 'valid', activation = 'relu', input_shape=(256,256,3)))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2), strides = 2, padding = 'valid'))

model.add(Conv2D(64, kernel_size = (3,3), padding = 'valid', activation = 'relu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2), strides = 2, padding = 'valid'))

model.add(Conv2D(128, kernel_size = (3,3), padding = 'valid', activation = 'relu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2), strides = 2, padding = 'valid'))

model.add(Flatten())

model.add(Dense(128, activation = 'relu'))
# model.add(Dropout(0.1))
model.add(Dense(64, activation = 'relu'))
# model.add(Dropout(0.1))
model.add(Dense(1, activation = 'sigmoid'))
model.summary()

# %%
train_generator

# %%
model.compile(optimizer= "adam", loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
moodel1 = model.fit(train_ds , epochs = 10 , validation_data = validation_ds)

# %%
inputs=tf.Tensor(shape=(None, 256, 256, 3), dtype='float32')

# %%
model1 = model.fit(train_batches, epochs = 10,  validation_data = validation_ds)

# %%
print(history.history)

# %%
acc = model1.history['accuracy']
val_acc = model1.history['val_accuracy']
loss =model1.history['loss']
val_loss = model1.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc', color = 'r')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss', color = 'r')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
plt.plot(history['loss'], color = 'red', label = 'train')
plt.plot(history['val_loss'], color = 'blue', label = 'test')
plt.legend()
plt.show()

# %% [markdown]
# # New Section
